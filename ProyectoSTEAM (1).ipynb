# %% [markdown]
# # **Proyecto: GATO** 🐈⭕❌
#
# ***Intrucciones:***
#
#
# 1.Los jugadores tienen que poner su nombre
#
# 2.El jugador 1 tiene que escojer una casilla del 1 al 9
#
# 3.El jugador 2 tiene que escojer una casilla dependiendo de cuales queden
#
# 4.Los jugadores tienen que seguir escojiendo una casilla hasta que alguno de los dos gane o se terminen las casillas

# %%
print("Guia tu tiro por el siguiente diagrama del juego:")
print(1, "|", 2, "|", 3)
print("- + - + -")
print(4, "|", 5, "|", 6)
print("- + - + -")
print(7, "|", 8, "|", 9)
print()
# Out:
# Guia tu tiro por el siguiente diagrama del juego:
# 1 | 2 | 3
# - + - + -
# 4 | 5 | 6
# - + - + -
# 7 | 8 | 9

# %%
print("┌───────────────────────────────────┐")
print("│ ⭐ Bienvenido al juego michimatch ⭐│")
print("└───────────────────────────────────┘")
# Out:
# ┌───────────────────────────────────┐
# │ ⭐ Bienvenido al juego michimatch ⭐│
# └───────────────────────────────────┘

# %%
seguir=True

var1 = ""
var2 = ""
var3 = ""
var4 = ""
var5 = ""
var6 = ""
var7 = ""
var8 = ""
var9 = ""

j1=input("Dime el nombre del jugador 1:")
j2=input("dime tu nombre")

while (seguir):
  c1=int(input(j1+ " dime que casilla escojes: "))
  #Linea de código para almacenar en la variable indicada el valor del jugador.
  globals()[f"var{c1}"] = j1

  c2=int(input(j2+ " dime que casilla escojes: "))
  globals()[f"var{c2}"]= j2

  if(var1==j1 and var2==j1 and var3==j1):
    print ("gano", j1)
    seguir=False
  elif(var4==j1 and var5==j1 and var6==j1):
    print ("gano", j1)
    seguir=False
  elif(var7==j1 and var8==j1 and var9==j1):
    print ("gano", j1)
    seguir=False
  elif(var1==j1 and var4==j1 and var7==j1):
    print ("gano", j1)
    seguir=False
  elif(var2==j1 and var5==j1 and var8==j1):
    print ("gano", j1)
    seguir=False
  elif(var3==j1 and var6==j1 and var9==j1):
    print ("gano", j1)
    seguir=False
  elif(var1==j1 and var5==j1 and var9==j1):
    print ("gano", j1)
    seguir=False
  elif(var3==j1 and var5==j1 and var7==j1):
    print ("gano", j1)
    seguir=False
  elif(var1==j2 and var2==j2 and var3==j2):
    print ("gano", j2)
    seguir=False
  elif(var4==j2 and var5==j2 and var6==j2):
    print ("gano", j2)
    seguir=False
  elif(var7==j2 and var8==j2 and var9==j2):
    print ("gano", j2)
    seguir=False
  elif(var1==j2 and var4==j2 and var7==j2):
    print ("gano", j2)
    seguir=False
  elif(var2==j2 and var5==j2 and var8==j2):
    print ("gano", j2)
    seguir=False
  elif(var3==j2 and var6==j2 and var9==j2):
    print ("gano", j2)
    seguir=False
  elif(var1==j2 and var5==j2 and var9==j2):
    print ("gano", j2)
    seguir=False
  elif(var3==j2 and var5==j2 and var7==j2):
    print ("gano", j2)
    seguir=False

# %% [markdown]
# ## ***Integrantes:***
# *Isaac Emiliano Angeles Gomez
#
# *Zadquiel Perez Guerrero
#
# *Valentina Lopez Ortega
#
# *Romina Arteaga Mendoza
